# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 印出網路結構
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# WARNING:tensorflow:From C:\Users\kenbchu\.conda\envs\ai_env\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From C:\Users\kenbchu\.conda\envs\ai_env\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 1712 samples, validate on 428 samples
# Epoch 1/50
# 1712/1712 [==============================] - 2s 1ms/step - loss: 0.0067 - val_loss: 0.0023
#
# Epoch 00001: val_loss improved from inf to 0.00231, saving model to best_weights.h5
# Epoch 2/50
# 1712/1712 [==============================] - 1s 356us/step - loss: 0.0017 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00231 to 0.00186, saving model to best_weights.h5
# Epoch 3/50
# 1712/1712 [==============================] - 1s 352us/step - loss: 0.0013 - val_loss: 0.0020
#
# Epoch 00003: val_loss did not improve from 0.00186
# Epoch 4/50
# 1712/1712 [==============================] - 1s 352us/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00004: val_loss did not improve from 0.00186
# Epoch 5/50
# 1712/1712 [==============================] - 1s 348us/step - loss: 0.0011 - val_loss: 0.0019
#
# Epoch 00005: val_loss did not improve from 0.00186
# Epoch 6/50
# 1712/1712 [==============================] - 1s 378us/step - loss: 0.0010 - val_loss: 0.0018
#
# Epoch 00006: val_loss improved from 0.00186 to 0.00183, saving model to best_weights.h5
# Epoch 7/50
# 1712/1712 [==============================] - 1s 423us/step - loss: 9.2022e-04 - val_loss: 0.0016
#
# Epoch 00007: val_loss improved from 0.00183 to 0.00162, saving model to best_weights.h5
# Epoch 8/50
# 1712/1712 [==============================] - 1s 391us/step - loss: 7.5809e-04 - val_loss: 0.0015
#
# Epoch 00008: val_loss improved from 0.00162 to 0.00152, saving model to best_weights.h5
# Epoch 9/50
# 1712/1712 [==============================] - 1s 389us/step - loss: 6.8501e-04 - val_loss: 0.0013
#
# Epoch 00009: val_loss improved from 0.00152 to 0.00132, saving model to best_weights.h5
# Epoch 10/50
# 1712/1712 [==============================] - 1s 350us/step - loss: 6.0499e-04 - val_loss: 0.0012
#
# Epoch 00010: val_loss improved from 0.00132 to 0.00124, saving model to best_weights.h5
# Epoch 11/50
# 1712/1712 [==============================] - 1s 354us/step - loss: 5.3843e-04 - val_loss: 0.0011
#
# Epoch 00011: val_loss improved from 0.00124 to 0.00112, saving model to best_weights.h5
# Epoch 12/50
# 1712/1712 [==============================] - 1s 346us/step - loss: 4.9630e-04 - val_loss: 0.0011
#
# Epoch 00012: val_loss improved from 0.00112 to 0.00110, saving model to best_weights.h5
# Epoch 13/50
# 1712/1712 [==============================] - 1s 359us/step - loss: 4.6410e-04 - val_loss: 0.0010
#
# Epoch 00013: val_loss improved from 0.00110 to 0.00101, saving model to best_weights.h5
# Epoch 14/50
# 1712/1712 [==============================] - 1s 389us/step - loss: 4.3316e-04 - val_loss: 9.8955e-04
#
# Epoch 00014: val_loss improved from 0.00101 to 0.00099, saving model to best_weights.h5
# Epoch 15/50
# 1712/1712 [==============================] - 1s 394us/step - loss: 4.1149e-04 - val_loss: 9.9340e-04
#
# Epoch 00015: val_loss did not improve from 0.00099
# Epoch 16/50
# 1712/1712 [==============================] - 1s 351us/step - loss: 3.9054e-04 - val_loss: 9.0958e-04
#
# Epoch 00016: val_loss improved from 0.00099 to 0.00091, saving model to best_weights.h5
# Epoch 17/50
# 1712/1712 [==============================] - 1s 377us/step - loss: 3.8058e-04 - val_loss: 9.0172e-04
#
# Epoch 00017: val_loss improved from 0.00091 to 0.00090, saving model to best_weights.h5
# Epoch 18/50
# 1712/1712 [==============================] - 1s 421us/step - loss: 3.6970e-04 - val_loss: 8.6478e-04
#
# Epoch 00018: val_loss improved from 0.00090 to 0.00086, saving model to best_weights.h5
# Epoch 19/50
# 1712/1712 [==============================] - 1s 414us/step - loss: 3.5172e-04 - val_loss: 8.6892e-04
#
# Epoch 00019: val_loss did not improve from 0.00086
# Epoch 20/50
# 1712/1712 [==============================] - 1s 358us/step - loss: 3.2524e-04 - val_loss: 8.6800e-04
#
# Epoch 00020: val_loss did not improve from 0.00086
# Epoch 21/50
# 1712/1712 [==============================] - 1s 351us/step - loss: 3.1910e-04 - val_loss: 8.3297e-04
#
# Epoch 00021: val_loss improved from 0.00086 to 0.00083, saving model to best_weights.h5
# Epoch 22/50
# 1712/1712 [==============================] - 1s 352us/step - loss: 3.0663e-04 - val_loss: 8.3989e-04
#
# Epoch 00022: val_loss did not improve from 0.00083
# Epoch 23/50
# 1712/1712 [==============================] - 1s 358us/step - loss: 2.9787e-04 - val_loss: 8.6285e-04
#
# Epoch 00023: val_loss did not improve from 0.00083
# Epoch 24/50
# 1712/1712 [==============================] - 1s 351us/step - loss: 2.9212e-04 - val_loss: 8.0962e-04
#
# Epoch 00024: val_loss improved from 0.00083 to 0.00081, saving model to best_weights.h5
# Epoch 25/50
# 1712/1712 [==============================] - 1s 350us/step - loss: 2.8284e-04 - val_loss: 8.0778e-04
#
# Epoch 00025: val_loss improved from 0.00081 to 0.00081, saving model to best_weights.h5
# Epoch 26/50
# 1712/1712 [==============================] - 1s 360us/step - loss: 2.8654e-04 - val_loss: 8.0240e-04
#
# Epoch 00026: val_loss improved from 0.00081 to 0.00080, saving model to best_weights.h5
# Epoch 27/50
# 1712/1712 [==============================] - 1s 380us/step - loss: 2.6927e-04 - val_loss: 8.3401e-04
#
# Epoch 00027: val_loss did not improve from 0.00080
# Epoch 28/50
# 1712/1712 [==============================] - 1s 402us/step - loss: 2.7033e-04 - val_loss: 8.0295e-04
#
# Epoch 00028: val_loss did not improve from 0.00080
# Epoch 29/50
# 1712/1712 [==============================] - 1s 359us/step - loss: 2.6138e-04 - val_loss: 8.0459e-04
#
# Epoch 00029: val_loss did not improve from 0.00080
# Epoch 30/50
# 1712/1712 [==============================] - 1s 381us/step - loss: 2.5029e-04 - val_loss: 7.7822e-04
#
# Epoch 00030: val_loss improved from 0.00080 to 0.00078, saving model to best_weights.h5
# Epoch 31/50
# 1712/1712 [==============================] - 1s 386us/step - loss: 2.5356e-04 - val_loss: 8.2271e-04
#
# Epoch 00031: val_loss did not improve from 0.00078
# Epoch 32/50
# 1712/1712 [==============================] - 1s 392us/step - loss: 2.3724e-04 - val_loss: 8.0284e-04
#
# Epoch 00032: val_loss did not improve from 0.00078
# Epoch 33/50
# 1712/1712 [==============================] - 1s 413us/step - loss: 2.4612e-04 - val_loss: 8.0280e-04
#
# Epoch 00033: val_loss did not improve from 0.00078
# Epoch 34/50
# 1712/1712 [==============================] - 1s 433us/step - loss: 2.3626e-04 - val_loss: 7.8523e-04
#
# Epoch 00034: val_loss did not improve from 0.00078
# Epoch 35/50
# 1712/1712 [==============================] - 1s 432us/step - loss: 2.2856e-04 - val_loss: 7.8842e-04
#
# Epoch 00035: val_loss did not improve from 0.00078
# Epoch 36/50
# 1712/1712 [==============================] - 1s 376us/step - loss: 2.3163e-04 - val_loss: 7.7604e-04
#
# Epoch 00036: val_loss improved from 0.00078 to 0.00078, saving model to best_weights.h5
# Epoch 37/50
# 1712/1712 [==============================] - 1s 358us/step - loss: 2.2629e-04 - val_loss: 7.7454e-04
#
# Epoch 00037: val_loss improved from 0.00078 to 0.00077, saving model to best_weights.h5
# Epoch 38/50
# 1712/1712 [==============================] - 1s 369us/step - loss: 2.2139e-04 - val_loss: 7.6762e-04
#
# Epoch 00038: val_loss improved from 0.00077 to 0.00077, saving model to best_weights.h5
# Epoch 39/50
# 1712/1712 [==============================] - 1s 361us/step - loss: 2.1874e-04 - val_loss: 7.6315e-04
#
# Epoch 00039: val_loss improved from 0.00077 to 0.00076, saving model to best_weights.h5
# Epoch 40/50
# 1712/1712 [==============================] - 1s 360us/step - loss: 2.1142e-04 - val_loss: 7.5792e-04
#
# Epoch 00040: val_loss improved from 0.00076 to 0.00076, saving model to best_weights.h5
# Epoch 41/50
# 1712/1712 [==============================] - 1s 356us/step - loss: 2.1537e-04 - val_loss: 7.5752e-04
#
# Epoch 00041: val_loss improved from 0.00076 to 0.00076, saving model to best_weights.h5
# Epoch 42/50
# 1712/1712 [==============================] - 1s 366us/step - loss: 2.0726e-04 - val_loss: 7.6164e-04
#
# Epoch 00042: val_loss did not improve from 0.00076
# Epoch 43/50
# 1712/1712 [==============================] - 1s 365us/step - loss: 1.9754e-04 - val_loss: 7.6500e-04
#
# Epoch 00043: val_loss did not improve from 0.00076
# Epoch 44/50
# 1712/1712 [==============================] - 1s 364us/step - loss: 1.9744e-04 - val_loss: 7.6970e-04
#
# Epoch 00044: val_loss did not improve from 0.00076
# Epoch 45/50
# 1712/1712 [==============================] - 1s 370us/step - loss: 1.9759e-04 - val_loss: 7.6399e-04
#
# Epoch 00045: val_loss did not improve from 0.00076
# Epoch 46/50
# 1712/1712 [==============================] - 1s 349us/step - loss: 1.9777e-04 - val_loss: 7.4545e-04
#
# Epoch 00046: val_loss improved from 0.00076 to 0.00075, saving model to best_weights.h5
# Epoch 47/50
# 1712/1712 [==============================] - 1s 381us/step - loss: 2.0072e-04 - val_loss: 7.9277e-04
#
# Epoch 00047: val_loss did not improve from 0.00075
# Epoch 48/50
# 1712/1712 [==============================] - 1s 370us/step - loss: 1.9487e-04 - val_loss: 7.6073e-04
#
# Epoch 00048: val_loss did not improve from 0.00075
# Epoch 49/50
# 1712/1712 [==============================] - 1s 369us/step - loss: 1.9278e-04 - val_loss: 7.6782e-04
#
# Epoch 00049: val_loss did not improve from 0.00075
# Epoch 50/50
# 1712/1712 [==============================] - 1s 358us/step - loss: 1.8643e-04 - val_loss: 7.3846e-04
#
# Epoch 00050: val_loss improved from 0.00075 to 0.00074, saving model to best_weights.h5

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
imgs_train.shape
# Out:
# (2140, 96, 96)

# %%
points_train.shape
# Out:
# (2140, 30)

# %%
# Your code
img_train_sample = imgs_train[0:1,::]
point_train_sample = points_train[0:1,:]

# %%
def show_figure(imgs, points):
    fig = plt.figure(figsize=(15,15))
    
    for i in range(imgs.shape[0]):
        ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
        plot_keypoints(imgs[i], np.squeeze(points[i]))

show_figure(img_train_sample, point_train_sample)

# %%
img_flip_sample = np.fliplr(img_train_sample[0].copy())
img_flip_sample = img_flip_sample.reshape(1, 96, 96)
point_flip_sample = point_train_sample[0].copy()
point_flip_sample[::2]*=-1
point_flip_sample = point_flip_sample.reshape(1, 30)
show_figure(img_flip_sample, point_flip_sample)
# Out:
# -0.037285715
# 0.037285715

# %%
img_all_sample = imgs_train.copy()

for ind in range(points_train.shape[0]):
    tmp_img_flip = np.fliplr(imgs_train[ind].copy())
    tmp_img_flip = tmp_img_flip.reshape(1, 96, 96)
    img_all_sample = np.concatenate((img_all_sample, tmp_img_flip), axis=0)

img_all_sample.shape
# Out:
# (4280, 96, 96)

# %%
points_all_sample = points_train.copy()

for ind in range(points_train.shape[0]):
    tmp_point_flip = points_train[ind].copy()
    tmp_point_flip[::2]*=-1
    tmp_point_flip = tmp_point_flip.reshape(1, 30)
    points_all_sample = np.concatenate((points_all_sample, tmp_point_flip), axis=0)

points_all_sample.shape
# Out:
# (4280, 30)

# %%
# training the model
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')

hist_flip_model = model.fit(img_all_sample.reshape(-1, 96, 96, 1), 
                       points_all_sample, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights_with_flip.h5')
# save the model
model.save('mode_with_flipl.h5')
# Out:
# Train on 3424 samples, validate on 856 samples
# Epoch 1/150
# 3424/3424 [==============================] - 2s 696us/step - loss: 0.0193 - val_loss: 0.0300
#
# Epoch 00001: val_loss did not improve from 0.00074
# Epoch 2/150
# 3424/3424 [==============================] - 1s 350us/step - loss: 0.0142 - val_loss: 0.0459
#
# Epoch 00002: val_loss did not improve from 0.00074
# Epoch 3/150
# 3424/3424 [==============================] - 1s 356us/step - loss: 0.0076 - val_loss: 0.0562
#
# Epoch 00003: val_loss did not improve from 0.00074
# Epoch 4/150
# 3424/3424 [==============================] - 1s 360us/step - loss: 0.0047 - val_loss: 0.0517
#
# Epoch 00004: val_loss did not improve from 0.00074
# Epoch 5/150
# 3424/3424 [==============================] - 1s 360us/step - loss: 0.0029 - val_loss: 0.0452
#
# Epoch 00005: val_loss did not improve from 0.00074
# Epoch 6/150
# 3424/3424 [==============================] - 1s 356us/step - loss: 0.0020 - val_loss: 0.0589
#
# Epoch 00006: val_loss did not improve from 0.00074
# Epoch 7/150
# 3424/3424 [==============================] - 1s 358us/step - loss: 0.0017 - val_loss: 0.0517
#
# Epoch 00007: val_loss did not improve from 0.00074
# Epoch 8/150
# 3424/3424 [==============================] - 1s 384us/step - loss: 0.0015 - val_loss: 0.0477
#
# Epoch 00008: val_loss did not improve from 0.00074
# Epoch 9/150
# 3424/3424 [==============================] - 1s 356us/step - loss: 0.0010 - val_loss: 0.0499
#
# Epoch 00009: val_loss did not improve from 0.00074
# Epoch 10/150
# 3424/3424 [==============================] - 1s 371us/step - loss: 9.6366e-04 - val_loss: 0.0515
#
# Epoch 00010: val_loss did not improve from 0.00074
# Epoch 11/150
# 3424/3424 [==============================] - ETA: 0s - loss: 7.8291e-0 - 1s 366us/step - loss: 7.8222e-04 - val_loss: 0.0521
#
# Epoch 00011: val_loss did not improve from 0.00074
# Epoch 12/150
# 3424/3424 [==============================] - 1s 353us/step - loss: 6.9407e-04 - val_loss: 0.0502
#
# Epoch 00012: val_loss did not improve from 0.00074
# Epoch 13/150
# 3424/3424 [==============================] - 1s 366us/step - loss: 6.4344e-04 - val_loss: 0.0503
#
# Epoch 00013: val_loss did not improve from 0.00074
# Epoch 14/150
# 3424/3424 [==============================] - 1s 400us/step - loss: 6.0369e-04 - val_loss: 0.0472
#
# Epoch 00014: val_loss did not improve from 0.00074
# Epoch 15/150
# 3424/3424 [==============================] - 1s 384us/step - loss: 5.5707e-04 - val_loss: 0.0506
#
# Epoch 00015: val_loss did not improve from 0.00074
# Epoch 16/150
# 3424/3424 [==============================] - 1s 408us/step - loss: 5.4188e-04 - val_loss: 0.0503
#
# Epoch 00016: val_loss did not improve from 0.00074
# Epoch 17/150
# 3424/3424 [==============================] - 1s 376us/step - loss: 5.1457e-04 - val_loss: 0.0489
#
# Epoch 00017: val_loss did not improve from 0.00074
# Epoch 18/150
# 3424/3424 [==============================] - 1s 359us/step - loss: 4.8804e-04 - val_loss: 0.0498
#
# Epoch 00018: val_loss did not improve from 0.00074
# Epoch 19/150
# 3424/3424 [==============================] - 1s 362us/step - loss: 4.7619e-04 - val_loss: 0.0487
#
# Epoch 00019: val_loss did not improve from 0.00074
# Epoch 20/150
# 3424/3424 [==============================] - 1s 387us/step - loss: 4.4684e-04 - val_loss: 0.0480
#
# Epoch 00020: val_loss did not improve from 0.00074
# Epoch 21/150
# 3424/3424 [==============================] - 1s 355us/step - loss: 4.3586e-04 - val_loss: 0.0502
#
# Epoch 00021: val_loss did not improve from 0.00074
# Epoch 22/150
# 3424/3424 [==============================] - 1s 366us/step - loss: 4.2049e-04 - val_loss: 0.0519
#
# Epoch 00022: val_loss did not improve from 0.00074
# Epoch 23/150
# 3424/3424 [==============================] - 1s 359us/step - loss: 4.0549e-04 - val_loss: 0.0502
#
# Epoch 00023: val_loss did not improve from 0.00074
# Epoch 24/150
# 3424/3424 [==============================] - 1s 355us/step - loss: 3.9656e-04 - val_loss: 0.0484
#
# Epoch 00024: val_loss did not improve from 0.00074
# Epoch 25/150
# 3424/3424 [==============================] - 1s 365us/step - loss: 3.8690e-04 - val_loss: 0.0494
#
# Epoch 00025: val_loss did not improve from 0.00074
# Epoch 26/150
# 3424/3424 [==============================] - 1s 360us/step - loss: 3.8646e-04 - val_loss: 0.0509
#
# Epoch 00026: val_loss did not improve from 0.00074
# Epoch 27/150
# 3424/3424 [==============================] - 1s 361us/step - loss: 3.7493e-04 - val_loss: 0.0476
#
# Epoch 00027: val_loss did not improve from 0.00074
# Epoch 28/150
# 3424/3424 [==============================] - 1s 364us/step - loss: 3.5712e-04 - val_loss: 0.0502
#
# Epoch 00028: val_loss did not improve from 0.00074
# Epoch 29/150
# 3424/3424 [==============================] - 1s 361us/step - loss: 3.6190e-04 - val_loss: 0.0499
#
# Epoch 00029: val_loss did not improve from 0.00074
# Epoch 30/150
# 3424/3424 [==============================] - 1s 365us/step - loss: 3.5696e-04 - val_loss: 0.0469
#
# Epoch 00030: val_loss did not improve from 0.00074
# Epoch 31/150
# 3424/3424 [==============================] - 1s 360us/step - loss: 3.3715e-04 - val_loss: 0.0503
#
# Epoch 00031: val_loss did not improve from 0.00074
# Epoch 32/150
# 3424/3424 [==============================] - 1s 360us/step - loss: 3.4232e-04 - val_loss: 0.0497
#
# Epoch 00032: val_loss did not improve from 0.00074
# Epoch 33/150
# 3424/3424 [==============================] - 1s 361us/step - loss: 3.3210e-04 - val_loss: 0.0503
#
# Epoch 00033: val_loss did not improve from 0.00074
# Epoch 34/150
# 3424/3424 [==============================] - 1s 360us/step - loss: 3.2055e-04 - val_loss: 0.0489
#
# Epoch 00034: val_loss did not improve from 0.00074
# Epoch 35/150
# 3424/3424 [==============================] - 1s 365us/step - loss: 3.1853e-04 - val_loss: 0.0496
#
# Epoch 00035: val_loss did not improve from 0.00074
# Epoch 36/150
# 3424/3424 [==============================] - 1s 360us/step - loss: 3.1548e-04 - val_loss: 0.0484
#
# Epoch 00036: val_loss did not improve from 0.00074
# Epoch 37/150
# 3424/3424 [==============================] - 1s 367us/step - loss: 3.0484e-04 - val_loss: 0.0482
#
# Epoch 00037: val_loss did not improve from 0.00074
# Epoch 38/150
# 3424/3424 [==============================] - 1s 364us/step - loss: 3.5658e-04 - val_loss: 0.0503
#
# Epoch 00038: val_loss did not improve from 0.00074
# Epoch 39/150
# 3424/3424 [==============================] - 1s 365us/step - loss: 5.4500e-04 - val_loss: 0.0424
#
# Epoch 00039: val_loss did not improve from 0.00074
# Epoch 40/150
# 3424/3424 [==============================] - 1s 360us/step - loss: 0.0036 - val_loss: 0.0498
#
# Epoch 00040: val_loss did not improve from 0.00074
# Epoch 41/150
# 3424/3424 [==============================] - 1s 359us/step - loss: 0.0016 - val_loss: 0.0452
#
# Epoch 00041: val_loss did not improve from 0.00074
# Epoch 42/150
# 3424/3424 [==============================] - 1s 365us/step - loss: 0.0012 - val_loss: 0.0533
#
# Epoch 00042: val_loss did not improve from 0.00074
# Epoch 43/150
# 3424/3424 [==============================] - 1s 361us/step - loss: 8.4266e-04 - val_loss: 0.0493
#
# Epoch 00043: val_loss did not improve from 0.00074
# Epoch 44/150
# 3424/3424 [==============================] - 1s 365us/step - loss: 6.5270e-04 - val_loss: 0.0519
#
# Epoch 00044: val_loss did not improve from 0.00074
# Epoch 45/150
# 3424/3424 [==============================] - 1s 365us/step - loss: 5.1104e-04 - val_loss: 0.0461
#
# Epoch 00045: val_loss did not improve from 0.00074
# Epoch 46/150
# 3424/3424 [==============================] - 1s 361us/step - loss: 4.6355e-04 - val_loss: 0.0505
#
# Epoch 00046: val_loss did not improve from 0.00074
# Epoch 47/150
# 3424/3424 [==============================] - 1s 394us/step - loss: 4.3145e-04 - val_loss: 0.0488
#
# Epoch 00047: val_loss did not improve from 0.00074
# Epoch 48/150
# 3424/3424 [==============================] - 1s 385us/step - loss: 3.8742e-04 - val_loss: 0.0475
#
# Epoch 00048: val_loss did not improve from 0.00074
# Epoch 49/150
# 3424/3424 [==============================] - 1s 364us/step - loss: 3.7533e-04 - val_loss: 0.0495
#
# Epoch 00049: val_loss did not improve from 0.00074
# Epoch 50/150
# 3424/3424 [==============================] - 1s 371us/step - loss: 3.6386e-04 - val_loss: 0.0496
#
# Epoch 00050: val_loss did not improve from 0.00074
# Epoch 51/150
# 3424/3424 [==============================] - 1s 360us/step - loss: 3.4711e-04 - val_loss: 0.0516
#
# Epoch 00051: val_loss did not improve from 0.00074
# Epoch 52/150
# 3424/3424 [==============================] - 1s 361us/step - loss: 3.3665e-04 - val_loss: 0.0489
#
# Epoch 00052: val_loss did not improve from 0.00074
# Epoch 53/150
# 3424/3424 [==============================] - 1s 355us/step - loss: 3.3197e-04 - val_loss: 0.0508
#
# Epoch 00053: val_loss did not improve from 0.00074
# Epoch 54/150
# 3424/3424 [==============================] - 1s 360us/step - loss: 3.2280e-04 - val_loss: 0.0485
#
# Epoch 00054: val_loss did not improve from 0.00074
# Epoch 55/150
# 3424/3424 [==============================] - 1s 360us/step - loss: 3.1429e-04 - val_loss: 0.0490
#
# Epoch 00055: val_loss did not improve from 0.00074
# Epoch 56/150
# 3424/3424 [==============================] - 1s 361us/step - loss: 3.1676e-04 - val_loss: 0.0504
#
# Epoch 00056: val_loss did not improve from 0.00074
# Epoch 57/150
# 3424/3424 [==============================] - 1s 360us/step - loss: 3.0490e-04 - val_loss: 0.0515
#
# Epoch 00057: val_loss did not improve from 0.00074
# Epoch 58/150
# 3424/3424 [==============================] - 1s 361us/step - loss: 3.0172e-04 - val_loss: 0.0514
#
# Epoch 00058: val_loss did not improve from 0.00074
# Epoch 59/150
# 3424/3424 [==============================] - 1s 360us/step - loss: 3.0067e-04 - val_loss: 0.0511
#
# Epoch 00059: val_loss did not improve from 0.00074
# Epoch 60/150
# 3424/3424 [==============================] - 1s 360us/step - loss: 2.9637e-04 - val_loss: 0.0510
#
# Epoch 00060: val_loss did not improve from 0.00074
# Epoch 61/150
# 3424/3424 [==============================] - 1s 364us/step - loss: 2.9579e-04 - val_loss: 0.0497
#
# Epoch 00061: val_loss did not improve from 0.00074
# Epoch 62/150
# 3424/3424 [==============================] - 1s 361us/step - loss: 2.7892e-04 - val_loss: 0.0498
#
# Epoch 00062: val_loss did not improve from 0.00074
# Epoch 63/150
# 3424/3424 [==============================] - 1s 360us/step - loss: 2.7767e-04 - val_loss: 0.0502
#
# Epoch 00063: val_loss did not improve from 0.00074
# Epoch 64/150
# 3424/3424 [==============================] - 1s 383us/step - loss: 2.7792e-04 - val_loss: 0.0497
#
# Epoch 00064: val_loss did not improve from 0.00074
# Epoch 65/150
# 3424/3424 [==============================] - 1s 358us/step - loss: 2.7658e-04 - val_loss: 0.0496
#
# Epoch 00065: val_loss did not improve from 0.00074
# Epoch 66/150
# 3424/3424 [==============================] - 1s 363us/step - loss: 2.7336e-04 - val_loss: 0.0500
#
# Epoch 00066: val_loss did not improve from 0.00074
# Epoch 67/150
# 3424/3424 [==============================] - 1s 365us/step - loss: 2.6835e-04 - val_loss: 0.0513
#
# Epoch 00067: val_loss did not improve from 0.00074
# Epoch 68/150
# 3424/3424 [==============================] - 1s 362us/step - loss: 2.6660e-04 - val_loss: 0.0501
#
# Epoch 00068: val_loss did not improve from 0.00074
# Epoch 69/150
# 3424/3424 [==============================] - 1s 370us/step - loss: 2.6715e-04 - val_loss: 0.0498
#
# Epoch 00069: val_loss did not improve from 0.00074
# Epoch 70/150
# 3424/3424 [==============================] - 1s 366us/step - loss: 2.5885e-04 - val_loss: 0.0518
#
# Epoch 00070: val_loss did not improve from 0.00074
# Epoch 71/150
# 3424/3424 [==============================] - 1s 368us/step - loss: 2.6466e-04 - val_loss: 0.0499
#
# Epoch 00071: val_loss did not improve from 0.00074
# Epoch 72/150
# 3424/3424 [==============================] - 1s 360us/step - loss: 2.6090e-04 - val_loss: 0.0496
#
# Epoch 00072: val_loss did not improve from 0.00074
# Epoch 73/150
# 3424/3424 [==============================] - 1s 359us/step - loss: 2.6585e-04 - val_loss: 0.0507
#
# Epoch 00073: val_loss did not improve from 0.00074
# Epoch 74/150
# 3424/3424 [==============================] - 1s 367us/step - loss: 2.5737e-04 - val_loss: 0.0490
#
# Epoch 00074: val_loss did not improve from 0.00074
# Epoch 75/150
# 3424/3424 [==============================] - 1s 385us/step - loss: 2.5480e-04 - val_loss: 0.0486
#
# Epoch 00075: val_loss did not improve from 0.00074
# Epoch 76/150
# 3424/3424 [==============================] - 1s 360us/step - loss: 2.5088e-04 - val_loss: 0.0510
#
# Epoch 00076: val_loss did not improve from 0.00074
# Epoch 77/150
# 3424/3424 [==============================] - 1s 356us/step - loss: 2.4961e-04 - val_loss: 0.0500
#
# Epoch 00077: val_loss did not improve from 0.00074
# Epoch 78/150
# 3424/3424 [==============================] - 1s 353us/step - loss: 2.4808e-04 - val_loss: 0.0501
#
# Epoch 00078: val_loss did not improve from 0.00074
# Epoch 79/150
# 3424/3424 [==============================] - 1s 357us/step - loss: 2.3879e-04 - val_loss: 0.0498-
#
# Epoch 00079: val_loss did not improve from 0.00074
# Epoch 80/150
# 3424/3424 [==============================] - 1s 353us/step - loss: 2.3856e-04 - val_loss: 0.0514
#
# Epoch 00080: val_loss did not improve from 0.00074
# Epoch 81/150
# 3424/3424 [==============================] - 1s 355us/step - loss: 2.3893e-04 - val_loss: 0.0515
#
# Epoch 00081: val_loss did not improve from 0.00074
# Epoch 82/150
# 3424/3424 [==============================] - 1s 356us/step - loss: 2.3661e-04 - val_loss: 0.0481
#
# Epoch 00082: val_loss did not improve from 0.00074
# Epoch 83/150
# 3424/3424 [==============================] - 1s 360us/step - loss: 2.4888e-04 - val_loss: 0.0506
#
# Epoch 00083: val_loss did not improve from 0.00074
# Epoch 84/150
# 3424/3424 [==============================] - 1s 355us/step - loss: 2.4369e-04 - val_loss: 0.0486
#
# Epoch 00084: val_loss did not improve from 0.00074
# Epoch 85/150
# 3424/3424 [==============================] - 1s 355us/step - loss: 2.3691e-04 - val_loss: 0.0492
#
# Epoch 00085: val_loss did not improve from 0.00074
# Epoch 86/150
# 3424/3424 [==============================] - 1s 351us/step - loss: 2.3670e-04 - val_loss: 0.0493
#
# Epoch 00086: val_loss did not improve from 0.00074
# Epoch 87/150
# 3424/3424 [==============================] - 1s 360us/step - loss: 2.3464e-04 - val_loss: 0.0527
#
# Epoch 00087: val_loss did not improve from 0.00074
# Epoch 88/150
# 3424/3424 [==============================] - 1s 355us/step - loss: 2.2895e-04 - val_loss: 0.0518A: 0s - loss: 2.2738e
#
# Epoch 00088: val_loss did not improve from 0.00074
# Epoch 89/150
# 3424/3424 [==============================] - 1s 354us/step - loss: 2.3071e-04 - val_loss: 0.0501
#
# Epoch 00089: val_loss did not improve from 0.00074
# Epoch 90/150
# 3424/3424 [==============================] - 1s 357us/step - loss: 2.2749e-04 - val_loss: 0.0522
#
# Epoch 00090: val_loss did not improve from 0.00074
# Epoch 91/150
# 3424/3424 [==============================] - 1s 355us/step - loss: 2.5316e-04 - val_loss: 0.0499
#
# Epoch 00091: val_loss did not improve from 0.00074
# Epoch 92/150
# 3424/3424 [==============================] - 1s 356us/step - loss: 6.3786e-04 - val_loss: 0.0527-0
#
# Epoch 00092: val_loss did not improve from 0.00074
# Epoch 93/150
# 3424/3424 [==============================] - 1s 357us/step - loss: 0.0019 - val_loss: 0.0466
#
# Epoch 00093: val_loss did not improve from 0.00074
# Epoch 94/150
# 3424/3424 [==============================] - 1s 369us/step - loss: 0.0014 - val_loss: 0.0525
#
# Epoch 00094: val_loss did not improve from 0.00074
# Epoch 95/150
# 3424/3424 [==============================] - 1s 379us/step - loss: 8.7859e-04 - val_loss: 0.0461
#
# Epoch 00095: val_loss did not improve from 0.00074
# Epoch 96/150
# 3424/3424 [==============================] - 1s 398us/step - loss: 6.6411e-04 - val_loss: 0.0491
#
# Epoch 00096: val_loss did not improve from 0.00074
# Epoch 97/150
# 3424/3424 [==============================] - 1s 365us/step - loss: 4.4606e-04 - val_loss: 0.0465
#
# Epoch 00097: val_loss did not improve from 0.00074
# Epoch 98/150
# 3424/3424 [==============================] - 1s 363us/step - loss: 3.9498e-04 - val_loss: 0.0484
#
# Epoch 00098: val_loss did not improve from 0.00074
# Epoch 99/150
# 3424/3424 [==============================] - 1s 362us/step - loss: 3.5912e-04 - val_loss: 0.0490
#
# Epoch 00099: val_loss did not improve from 0.00074
# Epoch 100/150
# 3424/3424 [==============================] - 1s 366us/step - loss: 3.3562e-04 - val_loss: 0.0498
#
# Epoch 00100: val_loss did not improve from 0.00074
# Epoch 101/150
# 3424/3424 [==============================] - 1s 365us/step - loss: 3.1494e-04 - val_loss: 0.0494
# Epoch 00101: val_loss did not improve from 0.00074
# Epoch 102/150
# 3424/3424 [==============================] - 1s 359us/step - loss: 2.9695e-04 - val_loss: 0.0479
#
# Epoch 00102: val_loss did not improve from 0.00074
# Epoch 103/150
# 3424/3424 [==============================] - 1s 370us/step - loss: 2.8743e-04 - val_loss: 0.0485
#
# Epoch 00103: val_loss did not improve from 0.00074
# Epoch 104/150
# 3424/3424 [==============================] - 1s 365us/step - loss: 2.8609e-04 - val_loss: 0.0487
#
# Epoch 00104: val_loss did not improve from 0.00074
# Epoch 105/150
# 3424/3424 [==============================] - 1s 357us/step - loss: 2.7702e-04 - val_loss: 0.0481
#
# Epoch 00105: val_loss did not improve from 0.00074
# Epoch 106/150
# 3424/3424 [==============================] - 1s 360us/step - loss: 2.7175e-04 - val_loss: 0.0485
#
# Epoch 00106: val_loss did not improve from 0.00074
# Epoch 107/150
# 3424/3424 [==============================] - 1s 374us/step - loss: 2.5903e-04 - val_loss: 0.0497
#
# Epoch 00107: val_loss did not improve from 0.00074
# Epoch 108/150
# 3424/3424 [==============================] - 1s 365us/step - loss: 2.5689e-04 - val_loss: 0.0487
#
# Epoch 00108: val_loss did not improve from 0.00074
# Epoch 109/150
# 3424/3424 [==============================] - 1s 365us/step - loss: 2.5443e-04 - val_loss: 0.0495
#
# Epoch 00109: val_loss did not improve from 0.00074
# Epoch 110/150
# 3424/3424 [==============================] - 1s 365us/step - loss: 2.4936e-04 - val_loss: 0.0480
#
# Epoch 00110: val_loss did not improve from 0.00074
# Epoch 111/150
# 3424/3424 [==============================] - 1s 361us/step - loss: 2.4989e-04 - val_loss: 0.0488
#
# Epoch 00111: val_loss did not improve from 0.00074
# Epoch 112/150
# 3424/3424 [==============================] - 1s 365us/step - loss: 2.4871e-04 - val_loss: 0.0476
#
# Epoch 00112: val_loss did not improve from 0.00074
# Epoch 113/150
# 3424/3424 [==============================] - 1s 365us/step - loss: 2.3924e-04 - val_loss: 0.0485
#
# Epoch 00113: val_loss did not improve from 0.00074
# Epoch 114/150
# 3424/3424 [==============================] - 1s 361us/step - loss: 2.4038e-04 - val_loss: 0.0486
#
# Epoch 00114: val_loss did not improve from 0.00074
# Epoch 115/150
# 3424/3424 [==============================] - 1s 365us/step - loss: 2.4182e-04 - val_loss: 0.0498
#
# Epoch 00115: val_loss did not improve from 0.00074
# Epoch 116/150
# 3424/3424 [==============================] - 1s 365us/step - loss: 2.4171e-04 - val_loss: 0.0494
#
# Epoch 00116: val_loss did not improve from 0.00074
# Epoch 117/150
# 3424/3424 [==============================] - 1s 360us/step - loss: 2.3794e-04 - val_loss: 0.0489
#
# Epoch 00117: val_loss did not improve from 0.00074
# Epoch 118/150
# 3424/3424 [==============================] - 1s 370us/step - loss: 2.3401e-04 - val_loss: 0.0493
#
# Epoch 00118: val_loss did not improve from 0.00074
# Epoch 119/150
# 3424/3424 [==============================] - 1s 361us/step - loss: 2.3440e-04 - val_loss: 0.0491
#
# Epoch 00119: val_loss did not improve from 0.00074
# Epoch 120/150
# 3424/3424 [==============================] - 1s 365us/step - loss: 2.3411e-04 - val_loss: 0.0486
#
# Epoch 00120: val_loss did not improve from 0.00074
# Epoch 121/150
# 3424/3424 [==============================] - 1s 365us/step - loss: 2.2958e-04 - val_loss: 0.0480
#
# Epoch 00121: val_loss did not improve from 0.00074
# Epoch 122/150
# 3424/3424 [==============================] - 1s 365us/step - loss: 2.2764e-04 - val_loss: 0.0501
#
# Epoch 00122: val_loss did not improve from 0.00074
# Epoch 123/150
# 3424/3424 [==============================] - 1s 361us/step - loss: 2.2864e-04 - val_loss: 0.0476
#
# Epoch 00123: val_loss did not improve from 0.00074
# Epoch 124/150
# 3424/3424 [==============================] - 1s 365us/step - loss: 2.2796e-04 - val_loss: 0.0475
#
# Epoch 00124: val_loss did not improve from 0.00074
# Epoch 125/150
# 3424/3424 [==============================] - 1s 365us/step - loss: 2.2603e-04 - val_loss: 0.0510
#
# Epoch 00125: val_loss did not improve from 0.00074
# Epoch 126/150
# 3424/3424 [==============================] - 1s 364us/step - loss: 2.2521e-04 - val_loss: 0.0485
#
# Epoch 00126: val_loss did not improve from 0.00074
# Epoch 127/150
# 3424/3424 [==============================] - 1s 366us/step - loss: 2.2632e-04 - val_loss: 0.0483
#
# Epoch 00127: val_loss did not improve from 0.00074
# Epoch 128/150
# 3424/3424 [==============================] - 1s 365us/step - loss: 2.2539e-04 - val_loss: 0.0482
#
# Epoch 00128: val_loss did not improve from 0.00074
# Epoch 129/150
# 3424/3424 [==============================] - 1s 360us/step - loss: 2.2280e-04 - val_loss: 0.0484
#
# Epoch 00129: val_loss did not improve from 0.00074
# Epoch 130/150
# 3424/3424 [==============================] - 1s 365us/step - loss: 2.2214e-04 - val_loss: 0.0502
#
# Epoch 00130: val_loss did not improve from 0.00074
# Epoch 131/150
# 3424/3424 [==============================] - 1s 365us/step - loss: 2.1752e-04 - val_loss: 0.0488
#
# Epoch 00131: val_loss did not improve from 0.00074
# Epoch 132/150
# 3424/3424 [==============================] - 1s 365us/step - loss: 2.1297e-04 - val_loss: 0.0485
#
# Epoch 00132: val_loss did not improve from 0.00074
# Epoch 133/150
# 3424/3424 [==============================] - 1s 365us/step - loss: 2.1589e-04 - val_loss: 0.0492
#
# Epoch 00133: val_loss did not improve from 0.00074
# Epoch 134/150
# 3424/3424 [==============================] - 1s 365us/step - loss: 2.2034e-04 - val_loss: 0.0484
#
# Epoch 00134: val_loss did not improve from 0.00074
# Epoch 135/150
# 3424/3424 [==============================] - 1s 361us/step - loss: 2.1256e-04 - val_loss: 0.0507
#
# Epoch 00135: val_loss did not improve from 0.00074
# Epoch 136/150
# 3424/3424 [==============================] - 1s 365us/step - loss: 2.1469e-04 - val_loss: 0.0488
#
# Epoch 00136: val_loss did not improve from 0.00074
# Epoch 137/150
# 3424/3424 [==============================] - 1s 365us/step - loss: 2.1041e-04 - val_loss: 0.0510
#
# Epoch 00137: val_loss did not improve from 0.00074
# Epoch 138/150
# 3424/3424 [==============================] - 1s 365us/step - loss: 2.1301e-04 - val_loss: 0.0499
#
# Epoch 00138: val_loss did not improve from 0.00074
# Epoch 139/150
# 3424/3424 [==============================] - 1s 365us/step - loss: 2.1519e-04 - val_loss: 0.0493
#
# Epoch 00139: val_loss did not improve from 0.00074
# Epoch 140/150
# 3424/3424 [==============================] - 1s 366us/step - loss: 2.0845e-04 - val_loss: 0.0495
#
# Epoch 00140: val_loss did not improve from 0.00074
# Epoch 141/150
# 3424/3424 [==============================] - 1s 365us/step - loss: 2.1133e-04 - val_loss: 0.0503
#
# Epoch 00141: val_loss did not improve from 0.00074
# Epoch 142/150
# 3424/3424 [==============================] - 1s 365us/step - loss: 2.1290e-04 - val_loss: 0.0494
#
# Epoch 00142: val_loss did not improve from 0.00074
# Epoch 143/150
# 3424/3424 [==============================] - 1s 361us/step - loss: 2.0577e-04 - val_loss: 0.0503
#
# Epoch 00143: val_loss did not improve from 0.00074
# Epoch 144/150
# 3424/3424 [==============================] - 1s 366us/step - loss: 2.1022e-04 - val_loss: 0.0498
#
# Epoch 00144: val_loss did not improve from 0.00074
# Epoch 145/150
# 3424/3424 [==============================] - 1s 365us/step - loss: 2.0956e-04 - val_loss: 0.0466
#
# Epoch 00145: val_loss did not improve from 0.00074
# Epoch 146/150
# 3424/3424 [==============================] - 1s 365us/step - loss: 2.0764e-04 - val_loss: 0.0481
#
# Epoch 00146: val_loss did not improve from 0.00074
# Epoch 147/150
# 3424/3424 [==============================] - 1s 365us/step - loss: 2.0459e-04 - val_loss: 0.0488
#
# Epoch 00147: val_loss did not improve from 0.00074
# Epoch 148/150
# 3424/3424 [==============================] - 1s 365us/step - loss: 2.0497e-04 - val_loss: 0.0503
#
# Epoch 00148: val_loss did not improve from 0.00074
# Epoch 149/150
# 3424/3424 [==============================] - 1s 370us/step - loss: 2.1035e-04 - val_loss: 0.0491
#
# Epoch 00149: val_loss did not improve from 0.00074
# Epoch 150/150
# 3424/3424 [==============================] - 1s 361us/step - loss: 2.0896e-04 - val_loss: 0.0507
#
# Epoch 00150: val_loss did not improve from 0.00074

# %%
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_flip_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_flip_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))
